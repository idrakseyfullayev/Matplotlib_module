# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
type(plt)
# Out:
# module

# %%
type(plt.subplot)
# Out:
# function

# %%
np.random.random(10)
# Out:
# array([0.31608053, 0.611309  , 0.79610722, 0.02966748, 0.96138906,
#        0.10728664, 0.741381  , 0.43931605, 0.60734228, 0.6793908 ])

# %%
plt.subplot(1, 3, 1)
plt.plot(np.random.random(10))
plt.subplot(1, 3, 2)
plt.plot(np.random.random(10))
plt.subplot(1, 3, 3)
plt.plot(np.random.random(10))
plt.grid()
plt.show()

# %%
plt.subplot(1, 3, 1)
plt.plot(np.random.random(10))
plt.grid()
plt.subplot(1, 3, 2)
plt.plot(np.random.random(10))
plt.grid()
plt.subplot(1, 3, 3)
plt.plot(np.random.random(10))
plt.grid()
plt.show()

# %%
ax1 = plt.subplot(1, 3, 1)
plt.plot(np.random.random(10))
ax2 = plt.subplot(1, 3, 2)
plt.plot(np.random.random(10))
ax3 = plt.subplot(1, 3, 3)
plt.plot(np.random.random(10))
ax1.grid()
ax2.grid()
ax3.grid()
plt.show()

# %%
ax1 = plt.subplot(1, 3, 1)
plt.plot(np.random.random(10))
# ax2 = plt.subplot(1, 3, 2)
# plt.plot(np.random.random(10))
ax3 = plt.subplot(1, 3, 3)
plt.plot(np.random.random(10))
ax1.grid()
# ax2.grid()
ax3.grid()
plt.show()

# %%
ax1 = plt.subplot(2, 3, 1)
plt.plot(np.random.random(10))
ax2 = plt.subplot(2, 3, 2)
plt.plot(np.random.random(10))
ax3 = plt.subplot(2, 3, 3)
plt.plot(np.random.random(10))
ax4 = plt.subplot(2, 1, 2)
plt.plot(np.random.random(10))
ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()
plt.show()

# %%
ax1 = plt.subplot(231)
plt.plot(np.random.random(10))
ax2 = plt.subplot(232)
plt.plot(np.random.random(10))
ax3 = plt.subplot(233)
plt.plot(np.random.random(10))
ax4 = plt.subplot(212)
plt.plot(np.random.random(10))
ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()
plt.show()

# %%
f, ax = plt.subplots(2, 2)
ax[0, 0].plot(np.arange(0, 5, 0.2))
ax[0, 0].grid()
ax[0, 1].plot(np.arange(5, 0, -0.2))
ax[0, 1]. grid()
plt.show()

# %%
f, ax = plt.subplots(2, 2)
f.set_size_inches(7, 4)
f.set_facecolor('#eee')
ax[0, 0].plot(np.arange(0, 5, 0.2))
ax[0, 0].grid()
ax[0, 1].plot(np.arange(5, 0, -0.2))
ax[0, 1]. grid()
plt.show()

# %%
fig = plt.figure(figsize = (7, 4))
plt.plot(np.arange(5, 10))
plt.show()

# %%
fig = plt.figure(figsize = (4, 4))
plt.plot(np.arange(5, 10))
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_axes([0, 0, 0.5, 0.5])
ax1.plot(np.arange(0, 5, 0.2))
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_axes([0, 0, 1, 1])
ax1.plot(np.arange(0, 5, 0.2))
plt.show()

# %%
fig = plt.figure(figsize = (7, 4))
ax1 = fig.add_axes([0, 0, 1, 1])
ax1.plot(np.arange(0, 5, 0.2))
plt.show()

# %%
fig = plt.figure(figsize = (7, 4))
ax1 = fig.add_subplot(1, 1, 1)
ax1.plot(np.arange(0, 5, 0.2))
plt.show()

# %%
fig = plt.figure(figsize = (7, 4))
ax1 = fig.add_subplot(1, 3, 1)
ax1.plot(np.arange(0, 5, 0.2))
plt.show()

# %%
f, ax = plt.subplots()
f.set_size_inches(7, 4)
f.set_facecolor('#eee')
ax.plot(np.arange(0, 5, 0.2))
ax.plot(np.arange(5, 0, -0.2))
ax.grid()
plt.show()

# %%
f, ax = plt.subplots()
f.set_size_inches(7, 4)
f.set_facecolor('#eee')
ax.plot(np.arange(0, 5, 0.2), 'ro--', markerfacecolor = 'w', markersize = 5)
# ax.plot(np.arange(5, 0, -0.2))
ax.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

fig = plt.figure(figsize=(7, 4))
gs = GridSpec(ncols=3, nrows = 2, figure=fig)

ax1 = plt.subplot(gs[0, 0])
ax1.plot(np.arange(0, 5, 0.2))
ax2 = fig.add_subplot(gs[1, 0:2])
ax2.plot(np.random.random(10))
ax3 = fig.add_subplot(gs[:, 2])
ax3.plot(np.random.random(10))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

ws = [1, 2, 5]
hs = [2, 0.5]

fig = plt.figure(figsize=(7, 4))
gs = GridSpec(ncols=3, nrows = 2, figure=fig, width_ratios=ws, height_ratios=hs)

ax1 = plt.subplot(gs[0, 0])
ax1.plot(np.arange(0, 5, 0.2))
ax2 = fig.add_subplot(gs[1, 0:2])
ax2.plot(np.random.random(10))
ax3 = fig.add_subplot(gs[:, 2])
ax3.plot(np.random.random(10))
plt.show()
