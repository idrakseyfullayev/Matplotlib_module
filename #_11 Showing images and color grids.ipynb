# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

img = Image.open(r'C:\Users\dell\Desktop\img\Panda.jpg')

fig = plt.figure(figsize=(6, 4))
ax = fig.add_subplot()

ax.imshow(img)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

img = Image.open(r'C:\Users\dell\Desktop\img\Panda.jpg')

plt.imshow(img)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

# img = Image.open(r'C:\Users\dell\Desktop\img\Panda.jpg')

data = np.random.randint(0, 200, (100, 100))

plt.imshow(data)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

# img = Image.open(r'C:\Users\dell\Desktop\img\Panda.jpg')

data = np.random.randint(0, 200, (100, 100))

plt.imshow(data, cmap='plasma')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

img = Image.open(r'C:\Users\dell\Desktop\img\Panda.jpg')

# data = np.random.randint(0, 200, (100, 100))

plt.imshow(img, cmap='plasma')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

img = np.array(Image.open(r'C:\Users\dell\Desktop\img\Panda.jpg'))

# data = np.random.randint(0, 200, (100, 100))

plt.imshow(img, cmap='winter')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

img = np.array(Image.open(r'C:\Users\dell\Desktop\img\Panda_1.jpg'))

# data = np.random.randint(0, 200, (100, 100))

plt.imshow(img, cmap='gray')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

img = np.array(Image.open(r'C:\Users\dell\Desktop\img\Panda_1.jpg'))

# data = np.random.randint(0, 200, (100, 100))

plt.imshow(img, origin='lower', cmap='gray', aspect='equal', alpha=0.7)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

img = np.array(Image.open(r'C:\Users\dell\Desktop\img\Panda_1.jpg'))

# data = np.random.randint(0, 200, (100, 100))

b = plt.imshow(img, origin='lower', cmap='gray', aspect='equal', alpha=0.7)
plt.colorbar(b)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

img = np.array(Image.open(r'C:\Users\dell\Desktop\img\Panda.jpg'))

# data = np.random.randint(0, 200, (100, 100))

b = plt.imshow(img, cmap='winter')
plt.colorbar(b)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

img = np.array([[1, 2, 4, 4, 5], [3, 4, 5, 6, 7]])

# data = np.random.randint(0, 200, (100, 100))

plt.imshow(img)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

img = np.array([[1, 2, 4, 4, 5], [3, 4, 5, 6, 7]])

# data = np.random.randint(0, 200, (100, 100))

plt.imshow(img, 'plasma')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

img = np.array([[1, 2, 1, 2, 1], [2, 1, 2, 1, 2]])

# data = np.random.randint(0, 200, (100, 100))

plt.imshow(img, 'plasma')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

# img = np.array([[1, 2, 1, 2, 1], [2, 1, 2, 1, 2]])

data = np.random.randint(0, 200, (100, 100))

plt.pcolormesh(data)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

# img = np.array([[1, 2, 1, 2, 1], [2, 1, 2, 1, 2]])

data = np.random.randint(0, 200, (10, 10))

plt.pcolormesh(data, cmap='plasma', edgecolor = 'black')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

# img = np.array([[1, 2, 1, 2, 1], [2, 1, 2, 1, 2]])

data = np.random.randint(0, 200, (10, 10))

b = plt.pcolormesh(data, cmap='plasma', edgecolor = 'black')
plt.colorbar(b)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

fig = plt.figure(figsize=(6, 4))
ax = fig.add_subplot()

# img = Image.open(r'C:\Users\dell\Desktop\img\Panda.jpg')

data = np.random.randint(0, 200, (10, 10))

b = ax.pcolormesh(data, edgecolor='black', cmap='winter')

fig.colorbar(b)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

fig = plt.figure(figsize=(6, 4))
ax = fig.add_subplot()

# img = Image.open(r'C:\Users\dell\Desktop\img\Panda.jpg')

data = np.random.randint(0, 200, (10, 10))

b = ax.pcolorfast(data, cmap='gray')

fig.colorbar(b)

plt.show()
