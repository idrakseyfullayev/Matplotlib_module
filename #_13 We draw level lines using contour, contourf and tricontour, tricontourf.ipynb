 2.44929360e-16,  1.98669331e-01,  3.89418342e-01, ...,
#         -5.36572918e-01, -3.58229282e-01, -1.65604175e-01],
#        [ 2.44929360e-16,  1.98669331e-01,  3.89418342e-01, ...,
#         -5.36572918e-01, -3.58229282e-01, -1.65604175e-01]])

# %%
np.sin(y_grid)
# Out:
# array([[ 2.44929360e-16,  2.44929360e-16,  2.44929360e-16, ...,
#          2.44929360e-16,  2.44929360e-16,  2.44929360e-16],
#        [ 1.98669331e-01,  1.98669331e-01,  1.98669331e-01, ...,
#          1.98669331e-01,  1.98669331e-01,  1.98669331e-01],
#        [ 3.89418342e-01,  3.89418342e-01,  3.89418342e-01, ...,
#          3.89418342e-01,  3.89418342e-01,  3.89418342e-01],
#        ...,
#        [-5.36572918e-01, -5.36572918e-01, -5.36572918e-01, ...,
#         -5.36572918e-01, -5.36572918e-01, -5.36572918e-01],
#        [-3.58229282e-01, -3.58229282e-01, -3.58229282e-01, ...,
#         -3.58229282e-01, -3.58229282e-01, -3.58229282e-01],
#        [-1.65604175e-01, -1.65604175e-01, -1.65604175e-01, ...,
#         -1.65604175e-01, -1.65604175e-01, -1.65604175e-01]])

# %%
z_grid
# Out:
# array([[1.51957436e-33, 1.27309485e-18, 2.58026823e-18, ...,
#         3.65877424e-18, 2.36012005e-18, 1.05537533e-18],
#        [1.27309485e-18, 1.06659505e-03, 2.16174099e-03, ...,
#         3.06531010e-03, 1.97730151e-03, 8.84190290e-04],
#        [2.58026823e-18, 2.16174099e-03, 4.38134802e-03, ...,
#         6.21267321e-03, 4.00753193e-03, 1.79204881e-03],
#        ...,
#        [3.65877424e-18, 3.06531010e-03, 6.21267321e-03, ...,
#         8.80945960e-03, 5.68260866e-03, 2.54109319e-03],
#        [2.36012005e-18, 1.97730151e-03, 4.00753193e-03, ...,
#         5.68260866e-03, 3.66560977e-03, 1.63915142e-03],
#        [1.05537533e-18, 8.84190290e-04, 1.79204881e-03, ...,
#         2.54109319e-03, 1.63915142e-03, 7.32979650e-04]])

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7, 4))
ax_3d = fig.add_subplot(projection='3d')

x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)

z_grid = (np.sin(x_grid) * np.sin(y_grid)) / (x_grid * y_grid)

ax_3d.contour(x_grid, y_grid, z_grid)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7, 4))
ax_3d = fig.add_subplot(projection='3d')

x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)

z_grid = (np.sin(x_grid) * np.sin(y_grid)) / (x_grid * y_grid)

ax_3d.contourf(x_grid, y_grid, z_grid)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2)
fig.set_size_inches(8, 4)

x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)

z_grid = (np.sin(x_grid) * np.sin(y_grid)) / (x_grid * y_grid)

ax[0].contour(x_grid, y_grid, z_grid)
ax[1].contourf(x_grid, y_grid, z_grid)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2)
fig.set_size_inches(8, 4)

x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)

z_grid = (np.sin(x_grid) * np.sin(y_grid)) / (x_grid * y_grid)

c1 = ax[0].contour(x_grid, y_grid, z_grid)
ax[0].clabel(c1)

ax[1].contourf(x_grid, y_grid, z_grid)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2)
fig.set_size_inches(8, 4)

x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)

z_grid = (np.sin(x_grid) * np.sin(y_grid)) / (x_grid * y_grid)

c1 = ax[0].contour(x_grid, y_grid, z_grid)
c1.clabel()

ax[1].contourf(x_grid, y_grid, z_grid)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2)
fig.set_size_inches(8, 4)

x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)

z_grid = (np.sin(x_grid) * np.sin(y_grid)) / (x_grid * y_grid)

c1 = ax[0].contour(x_grid, y_grid, z_grid)
c1.clabel()

c2 = ax[1].contourf(x_grid, y_grid, z_grid)
c2.clabel()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2)
fig.set_size_inches(8, 4)

x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)

z_grid = (np.sin(x_grid) * np.sin(y_grid)) / (x_grid * y_grid)

c1 = ax[0].contour(x_grid, y_grid, z_grid, 15)
c1.clabel()

ax[1].contourf(x_grid, y_grid, z_grid)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2)
fig.set_size_inches(8, 4)

x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)

z_grid = (np.sin(x_grid) * np.sin(y_grid)) / (x_grid * y_grid)

c1 = ax[0].contour(x_grid, y_grid, z_grid, [-0.1, 0, 0.2, 0.5])
c1.clabel()

ax[1].contourf(x_grid, y_grid, z_grid)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2)
fig.set_size_inches(8, 4)

x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)

z_grid = (np.sin(x_grid) * np.sin(y_grid)) / (x_grid * y_grid)

c1 = ax[0].contour(x_grid, y_grid, z_grid, colors = 'g')
c1.clabel()

ax[1].contourf(x_grid, y_grid, z_grid)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2)
fig.set_size_inches(8, 4)

x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)

z_grid = (np.sin(x_grid) * np.sin(y_grid)) / (x_grid * y_grid)

c1 = ax[0].contour(x_grid, y_grid, z_grid, colors = ['g', 'b', 'r'])
c1.clabel()

ax[1].contourf(x_grid, y_grid, z_grid)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2)
fig.set_size_inches(8, 4)

x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)

z_grid = (np.sin(x_grid) * np.sin(y_grid)) / (x_grid * y_grid)

c1 = ax[0].contour(x_grid, y_grid, z_grid, cmap = "plasma")
c1.clabel()

ax[1].contourf(x_grid, y_grid, z_grid)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2)
fig.set_size_inches(8, 4)

x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)

z_grid = (np.sin(x_grid) * np.sin(y_grid)) / (x_grid * y_grid)

c1 = ax[0].contour(x_grid, y_grid, z_grid, cmap = "plasma")
c1.clabel(colors='k')

ax[1].contourf(x_grid, y_grid, z_grid)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2)
fig.set_size_inches(8, 4)

x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
x_grid, y_grid = np.meshgrid(x, y)

z_grid = (np.sin(x_grid) * np.sin(y_grid)) / (x_grid * y_grid)

c1 = ax[0].contour(x_grid, y_grid, z_grid, cmap = "plasma")
c1.clabel(colors='k', fmt='%.2f')

ax[1].contourf(x_grid, y_grid, z_grid)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
fig.set_size_inches(8, 4)

np.random.seed(7)
x = np.random.rand(100) * 4*np.pi - 2*np.pi
y = np.random.rand(100) * 4*np.pi - 2*np.pi
z = (np.sin(x) * np.sin(y)) / (1+ np.abs(x + y))

c1 = ax.tricontour(x, y, z, cmap = "plasma")
c1.clabel(colors='k', fmt='%.2f')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
fig.set_size_inches(8, 4)

np.random.seed(7)
x = np.random.rand(100) * 4*np.pi - 2*np.pi
y = np.random.rand(100) * 4*np.pi - 2*np.pi
z = (np.sin(x) * np.sin(y)) / (1+ np.abs(x + y))

c1 = ax.tricontourf(x, y, z, cmap = "plasma")
c1.clabel(colors='k', fmt='%.2f')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
