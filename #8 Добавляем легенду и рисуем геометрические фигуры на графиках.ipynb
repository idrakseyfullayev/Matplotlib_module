# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot()
ax1 = ax.plot(np.arange(0, 5, 0.25))
ax2 = ax.plot(np.arange(0, 10, 0.5))
ax.legend()

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot()
ax1 = ax.plot(np.arange(0, 5, 0.25), label = 'line1')
ax2 = ax.plot(np.arange(0, 10, 0.5), label = 'line2')

ax.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot()
ax1 = ax.plot(np.arange(0, 5, 0.25), '--o', label = 'line1')
ax2 = ax.plot(np.arange(0, 10, 0.5), ':s',  label = 'line2')

ax.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot()
ax1 = ax.plot(np.arange(0, 5, 0.25), '--o')
ax2 = ax.plot(np.arange(0, 10, 0.5), ':s')

ax.legend(['1', '2'])

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot()
ax1, = ax.plot(np.arange(0, 5, 0.25), '--o')
ax2, = ax.plot(np.arange(0, 10, 0.5), ':s')

ax.legend((ax2, ax1), ['line2', 'line1'])

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot()
ax1, = ax.plot(np.arange(0, 5, 0.25), '--o')
ax2, = ax.plot(np.arange(0, 10, 0.5), ':s')

ax.legend((ax2, ax1), ['line2', 'line1'], loc = 'upper right')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot()
ax1, = ax.plot(np.arange(0, 5, 0.25), '--o')
ax2, = ax.plot(np.arange(0, 10, 0.5), ':s')

ax.legend((ax2, ax1), ['line2', 'line1'], bbox_to_anchor = (0.5, 0.7))

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot()
ax1, = ax.plot(np.arange(0, 5, 0.25), '--o')
ax2, = ax.plot(np.arange(0, 10, 0.5), ':s')

ax.legend((ax2, ax1), [r'$f(x) = a \cdot b + c$', r'$f(x) = k \cdot x + b$'])

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot()
ax1, = ax.plot(np.arange(0, 5, 0.25), '--o')
ax2, = ax.plot(np.arange(0, 10, 0.5), ':s')

ax.legend((ax2, ax1), [r'$f(x) = a \cdot b + c$', r'$f(x) = k \cdot x + b$'], facecolor = '#aaa', framealpha = 1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot()
ax1, = ax.plot(np.arange(0, 5, 0.25), '--o')
ax2, = ax.plot(np.arange(0, 10, 0.5), ':s')

ax.legend((ax2, ax1), [r'$f(x) = a \cdot b + c$', r'$f(x) = k \cdot x + b$'], facecolor = '#aaa', framealpha = 0.3)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

l1 =Line2D([0, 1, 2, 3, 4], [0, 1, 4, 9, 16])

fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot()
ax1, = ax.plot(np.arange(0, 5, 0.25), '--o')
ax2, = ax.plot(np.arange(0, 10, 0.5), ':s')

ax.legend((ax2, ax1), [r'$f(x) = a \cdot b + c$', r'$f(x) = k \cdot x + b$'], facecolor = '#aaa', framealpha = 0.3)

ax.add_line(l1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

l1 =Line2D([0, 1, 2, 3, 4], [0, 1, 4, 9, 16])

fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot()
# ax1, = ax.plot(np.arange(0, 5, 0.25), '--o')
# ax2, = ax.plot(np.arange(0, 10, 0.5), ':s')

ax.legend((ax2, ax1), [r'$f(x) = a \cdot b + c$', r'$f(x) = k \cdot x + b$'], facecolor = '#aaa', framealpha = 0.3)

ax.add_line(l1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

l1 =Line2D([0, 1, 2, 3, 4], [0, 1, 4, 9, 16])

fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot()
# ax1, = ax.plot(np.arange(0, 5, 0.25), '--o')
# ax2, = ax.plot(np.arange(0, 10, 0.5), ':s')

ax.legend((ax2, ax1), [r'$f(x) = a \cdot b + c$', r'$f(x) = k \cdot x + b$'], facecolor = '#aaa', framealpha = 0.3)

ax.set(xlim=(0, 4), ylim=(0, 16))

ax.add_line(l1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

l1 = Line2D([0, 1, 2, 3, 4], [0, 1, 4, 9, 16])

fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot()
# ax1, = ax.plot(np.arange(0, 5, 0.25), '--o')
# ax2, = ax.plot(np.arange(0, 10, 0.5), ':s')

ax.legend((l1,), [r'$f(x) = a^2$'], facecolor = '#aaa', framealpha = 0.3)

ax.set(xlim=(0, 4), ylim=(0, 16))

ax.add_line(l1)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

x = np.arange(-2*np.pi, 2*np.pi, 0.1)
y = np.cos(x)
cos = Line2D(x, y)



fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot()


ax.legend((l1,), [r'$f(x) = a^2$'], facecolor = '#aaa', framealpha = 0.3)

ax.set(xlim=(0, 4), ylim=(0, 16))

ax.add_line(cos)

plt.show()

# %%
x
# Out:
# array([-6.28318531, -6.18318531, -6.08318531, -5.98318531, -5.88318531,
#        -5.78318531, -5.68318531, -5.58318531, -5.48318531, -5.38318531,
#        -5.28318531, -5.18318531, -5.08318531, -4.98318531, -4.88318531,
#        -4.78318531, -4.68318531, -4.58318531, -4.48318531, -4.38318531,
#        -4.28318531, -4.18318531, -4.08318531, -3.98318531, -3.88318531,
#        -3.78318531, -3.68318531, -3.58318531, -3.48318531, -3.38318531,
#        -3.28318531, -3.18318531, -3.08318531, -2.98318531, -2.88318531,
#        -2.78318531, -2.68318531, -2.58318531, -2.48318531, -2.38318531,
#        -2.28318531, -2.18318531, -2.08318531, -1.98318531, -1.88318531,
#        -1.78318531, -1.68318531, -1.58318531, -1.48318531, -1.38318531,
#        -1.28318531, -1.18318531, -1.08318531, -0.98318531, -0.88318531,
#        -0.78318531, -0.68318531, -0.58318531, -0.48318531, -0.38318531,
#        -0.28318531, -0.18318531, -0.08318531,  0.01681469,  0.11681469,
# ...

# %%
y
# Out:
# array([ 1.        ,  0.99500417,  0.98006658,  0.95533649,  0.92106099,
#         0.87758256,  0.82533561,  0.76484219,  0.69670671,  0.62160997,
#         0.54030231,  0.45359612,  0.36235775,  0.26749883,  0.16996714,
#         0.0707372 , -0.02919952, -0.12884449, -0.22720209, -0.32328957,
#        -0.41614684, -0.5048461 , -0.58850112, -0.66627602, -0.73739372,
#        -0.80114362, -0.85688875, -0.90407214, -0.94222234, -0.97095817,
#        -0.9899925 , -0.99913515, -0.99829478, -0.98747977, -0.96679819,
#        -0.93645669, -0.89675842, -0.84810003, -0.79096771, -0.7259323 ,
#        -0.65364362, -0.57482395, -0.49026082, -0.40079917, -0.30733287,
#        -0.2107958 , -0.11215253, -0.01238866,  0.08749898,  0.18651237,
#         0.28366219,  0.37797774,  0.46851667,  0.55437434,  0.63469288,
#         0.70866977,  0.77556588,  0.83471278,  0.88551952,  0.92747843,
#         0.96017029,  0.98326844,  0.9965421 ,  0.99985864,  0.99318492,
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

x = np.arange(-2*np.pi, 2*np.pi, 0.1)
y = np.cos(x)
cos = Line2D(x, y)



fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot()


ax.legend((l1,), [r'$f(x) = a^2$'], facecolor = '#aaa', framealpha = 0.3)

ax.set(xlim=(-2*np.pi, 2*np.pi), ylim=(-1, 1))

ax.add_line(cos)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

x = np.arange(-2*np.pi, 2*np.pi, 0.1)
y = np.cos(x)
cos = Line2D(x, y)



fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot()


ax.legend((l1,), [r'$f(x) = a^2$'], facecolor = '#aaa', framealpha = 0.3)

ax.set(xlim=(-7, 7), ylim=(-1.1, 1.1))

ax.add_line(cos)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

x = np.arange(-2*np.pi, 2*np.pi, 0.1)
y = np.cos(x)
cos = Line2D(x, y)

fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot()

ax.plot(x, y)


ax.legend((l1,), [r'$f(x) = a^2$'], facecolor = '#aaa', framealpha = 0.3)

ax.set(xlim=(-7, 7), ylim=(-1.1, 1.1))

# ax.add_line(cos)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.patches import *

# x = np.arange(-2*np.pi, 2*np.pi, 0.1)
# y = np.cos(x)
# cos = Line2D(x, y)

rec = Rectangle((0, 0), 2.5, 0.5, facecolor= 'g')

fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot()


ax.legend((l1,), [r'$f(x) = a^2$'], facecolor = '#aaa', framealpha = 0.3)

ax.set(xlim=(-7, 7), ylim=(-1.1, 1.1))

ax.add_patch(rec)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.patches import *

# x = np.arange(-2*np.pi, 2*np.pi, 0.1)
# y = np.cos(x)
# cos = Line2D(x, y)

rec = Rectangle((0, 0), 2.5, 0.5, facecolor= 'g')

fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot()


ax.legend((l1,), [r'$f(x) = a^2$'], facecolor = '#aaa', framealpha = 0.3)

ax.set(xlim=(0, 3), ylim=(0, 1))

ax.add_patch(rec)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

x = np.arange(-2*np.pi, 2*np.pi, 0.1)
y = np.cos(x)
cos = Line2D(x, y)

rec = Rectangle((0, 0), 2.5, 0.5, facecolor= 'g')

fig = plt.figure(figsize=(7,4))
ax = fig.add_subplot()

ax.plot(x, y)


ax.legend((l1,), [r'$f(x) = a^2$'], facecolor = '#aaa', framealpha = 0.3)

ax.set(xlim=(-7, 7), ylim=(-1.1, 1.1))

ax.add_line(cos)
ax.add_patch(rec)

plt.show()
