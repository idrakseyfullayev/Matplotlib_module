# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.subplots()

x = np.arange(-np.pi/2, np.pi, 0.1)
y = np.sin(x)

ax.plot(x, y)

ax.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.subplots()

x = np.arange(-np.pi/2, np.pi, 0.1)
y = np.sin(x)

ax.plot(x, y)

ax.set(xticklabels = [], yticklabels = [])

ax.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.subplots()

x = np.arange(-np.pi/2, np.pi, 0.1)
y = np.sin(x)

ax.plot(x, y)

ax.set_xticklabels([]) 
ax.set_yticklabels([])

ax.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7,4))
ax = fig.subplots()

x = np.arange(-np.pi/2, np.pi, 0.1)
y = np.sin(x)

ax.plot(x, y)

ax.set_xticklabels([-1, 1]) 
ax.set_yticklabels([])

ax.grid()
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_13436\1818136928.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([-1, 1])

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter

fig = plt.figure(figsize=(7,4))
ax = fig.subplots()

x = np.arange(-np.pi/2, np.pi, 0.1)
y = np.sin(x)

ax.plot(x, y)

# ax.set_xticklabels([]) 
# ax.set_yticklabels([])

ax.xaxis.set_major_formatter(NullFormatter())

ax.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter

fig = plt.figure(figsize=(7,4))
ax = fig.subplots()

x = np.arange(-np.pi/2, np.pi, 0.1)
y = np.sin(x)

ax.plot(x, y)

# ax.set_xticklabels([]) 
# ax.set_yticklabels([])

ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())

ax.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import IndexLocator, MultipleLocator, NullFormatter, FormatStrFormatter

fig = plt.figure(figsize=(7,4))
ax = fig.subplots()

x = np.arange(-np.pi/2, np.pi, 0.1)
y = np.sin(x)

ax.plot(x, y)

# ax.set_xticklabels([]) 
# ax.set_yticklabels([])

# ax.xaxis.set_major_locator(IndexLocator(0.5, 0))
ax.xaxis.set_major_locator(MultipleLocator(0.5))

ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
ax.yaxis.set_major_formatter(FormatStrFormatter('%d'))

ax.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import IndexLocator, MultipleLocator, NullFormatter, FormatStrFormatter

fig = plt.figure(figsize=(7,4))
ax = fig.subplots()

x = np.arange(-np.pi/2, np.pi, 0.1)
y = np.sin(x)

ax.plot(x, y)

# ax.set_xticklabels([]) 
# ax.set_yticklabels([])

# ax.xaxis.set_major_locator(IndexLocator(0.5, 0))
# ax.xaxis.set_major_locator(MultipleLocator(0.5))

# ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
ax.yaxis.set_major_formatter(FormatStrFormatter('%f'))

ax.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import IndexLocator, MultipleLocator, NullFormatter, FormatStrFormatter

fig = plt.figure(figsize=(7,4))
ax = fig.subplots()

x = np.arange(-np.pi/2, np.pi, 0.1)
y = np.sin(x)

ax.plot(x, y)

# ax.set_xticklabels([]) 
# ax.set_yticklabels([])

# ax.xaxis.set_major_locator(IndexLocator(0.5, 0))
# ax.xaxis.set_major_locator(MultipleLocator(0.5))

# ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))

ax.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import IndexLocator, MultipleLocator, NullFormatter, FormatStrFormatter

fig = plt.figure(figsize=(7,4))
ax = fig.subplots()

x = np.arange(-np.pi/2, np.pi, 0.1)
y = np.sin(x)

ax.plot(x, y)

# ax.set_xticklabels([]) 
# ax.set_yticklabels([])

# ax.xaxis.set_major_locator(IndexLocator(0.5, 0))
# ax.xaxis.set_major_locator(MultipleLocator(0.5))

ax.xaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.3f'))

ax.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import IndexLocator, MultipleLocator, NullFormatter, FormatStrFormatter

fig = plt.figure(figsize=(7,4))
ax = fig.subplots()

x = np.arange(-np.pi/2, np.pi, 0.1)
y = np.sin(x)

ax.plot(x, y)

# ax.set_xticklabels([]) 
# ax.set_yticklabels([])

# ax.xaxis.set_major_locator(IndexLocator(0.5, 0))
# ax.xaxis.set_major_locator(MultipleLocator(0.5))

ax.xaxis.set_major_formatter(FormatStrFormatter('x = %.2f'))
ax.yaxis.set_major_formatter(FormatStrFormatter('y = %.3f'))

ax.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import IndexLocator, MultipleLocator, NullFormatter, FormatStrFormatter, FuncFormatter

fig = plt.figure(figsize=(7,4))
ax = fig.subplots()

x = np.arange(-np.pi/2, np.pi, 0.1)
y = np.sin(x)

ax.plot(x, y)

# ax.set_xticklabels([]) 
# ax.set_yticklabels([])

# ax.xaxis.set_major_locator(IndexLocator(0.5, 0))
# ax.xaxis.set_major_locator(MultipleLocator(0.5))

def formatOy(x, pos):
    return f'[{x}]' if x < 0 else f"({x})"

# ax.xaxis.set_major_formatter(FormatStrFormatter('x = %.2f'))
ax.yaxis.set_major_formatter(FuncFormatter(formatOy))

ax.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import IndexLocator, MultipleLocator, NullFormatter, FormatStrFormatter, FuncFormatter

fig = plt.figure(figsize=(7,4))
ax = fig.subplots()

x = np.arange(-np.pi/2, np.pi, 0.1)
y = np.sin(x)

ax.plot(x, y)

# ax.set_xticklabels([]) 
# ax.set_yticklabels([])

# ax.xaxis.set_major_locator(IndexLocator(0.5, 0))
# ax.xaxis.set_major_locator(MultipleLocator(0.5))

# def formatOy(x, pos):
#     return f'[{x}]' if x < 0 else f"({x})"

# ax.xaxis.set_major_formatter(FormatStrFormatter('x = %.2f'))
ax.yaxis.set_major_formatter(FuncFormatter((lambda x, pos: f'[{x}]' if x < 0 else f'({x})') ))

ax.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import (IndexLocator, MultipleLocator, NullFormatter, FormatStrFormatter, FuncFormatter,
ScalarFormatter)

fig = plt.figure(figsize=(7,4))
ax = fig.subplots()

x = np.arange(-np.pi/2, np.pi, 0.1)
y = np.sin(x)

ax.plot(x, y * 1e10)

# ax.set_xticklabels([]) 
# ax.set_yticklabels([])

# ax.xaxis.set_major_locator(IndexLocator(0.5, 0))
# ax.xaxis.set_major_locator(MultipleLocator(0.5))

# def formatOy(x, pos):
#     return f'[{x}]' if x < 0 else f"({x})"

# ax.yaxis.set_major_formatter(ScalarFormatter())

ax.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import (IndexLocator, MultipleLocator, NullFormatter, FormatStrFormatter, FuncFormatter,
ScalarFormatter)

fig = plt.figure(figsize=(7,4))
ax = fig.subplots()

x = np.arange(-np.pi/2, np.pi, 0.1)
y = np.sin(x)

ax.plot(x, y * 1e5)

# ax.set_xticklabels([]) 
# ax.set_yticklabels([])

# ax.xaxis.set_major_locator(IndexLocator(0.5, 0))
# ax.xaxis.set_major_locator(MultipleLocator(0.5))

# def formatOy(x, pos):
#     return f'[{x}]' if x < 0 else f"({x})"

sf = ScalarFormatter()
sf.set_powerlimits((-4, 4))

ax.yaxis.set_major_formatter(sf)

ax.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import (IndexLocator, MultipleLocator, NullFormatter, FormatStrFormatter, FuncFormatter,
ScalarFormatter)

fig = plt.figure(figsize=(7,4))
ax = fig.subplots()

x = np.arange(-np.pi/2, np.pi, 0.1)
y = np.sin(x)

ax.plot(x, y * 1e5)

# ax.set_xticklabels([]) 
# ax.set_yticklabels([])

# ax.xaxis.set_major_locator(IndexLocator(0.5, 0))
# ax.xaxis.set_major_locator(MultipleLocator(0.5))

# def formatOy(x, pos):
#     return f'[{x}]' if x < 0 else f"({x})"

sf = ScalarFormatter()
sf.set_powerlimits((-6, 6))

ax.yaxis.set_major_formatter(sf)

ax.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import (IndexLocator, MultipleLocator, NullFormatter, FormatStrFormatter, FuncFormatter,
ScalarFormatter)

import matplotlib

matplotlib.rcParams['axes.formatter.limits'] = (-4, 4)

fig = plt.figure(figsize=(7,4))
ax = fig.subplots()

x = np.arange(-np.pi/2, np.pi, 0.1)
y = np.sin(x)

ax.plot(x, y * 1e5)

# ax.set_xticklabels([]) 
# ax.set_yticklabels([])

# ax.xaxis.set_major_locator(IndexLocator(0.5, 0))
# ax.xaxis.set_major_locator(MultipleLocator(0.5))

# def formatOy(x, pos):
#     return f'[{x}]' if x < 0 else f"({x})"

# sf = ScalarFormatter()
# sf.set_powerlimits((-4, 4))

# ax.yaxis.set_major_formatter(sf)

ax.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import (IndexLocator, MultipleLocator, FixedLocator, NullFormatter, FormatStrFormatter, FuncFormatter, 
ScalarFormatter, FixedFormatter)

fig = plt.figure(figsize=(7,4))
ax = fig.subplots()

x = np.arange(-np.pi/2, np.pi, 0.1)
y = np.sin(x)

ax.plot(x, y * 1e5)

ax.xaxis.set_major_formatter(FixedFormatter([-3, -2, -1, 0, 1, 3]))

ax.grid()
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_13436\2304648163.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.xaxis.set_major_formatter(FixedFormatter([-3, -2, -1, 0, 1, 3]))

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import (IndexLocator, MultipleLocator, FixedLocator, NullFormatter, FormatStrFormatter, FuncFormatter, 
ScalarFormatter, FixedFormatter)

fig = plt.figure(figsize=(7,4))
ax = fig.subplots()

x = np.arange(-np.pi/2, np.pi, 0.1)
y = np.sin(x)

ax.plot(x, y * 1e5)

ax.xaxis.set_major_locator(FixedLocator([-3, -2, -1, 0, 1, 3]))
ax.xaxis.set_major_formatter(FixedFormatter([-3, -2, -1, 0, 1, 3]))
# ax.xaxis.set_major_locator(FixedLocator([i for i in range(-3, 4)]))
# ax.xaxis.set_major_formatter(FixedFormatter(np.arange(-3,4)))

ax.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import (IndexLocator, MultipleLocator, FixedLocator, NullFormatter, FormatStrFormatter, FuncFormatter, 
ScalarFormatter, FixedFormatter)

fig = plt.figure(figsize=(7,4))
ax = fig.subplots()

x = np.arange(-np.pi/2, np.pi, 0.1)
y = np.sin(x)

ax.plot(x, y * 1e5)

ax.xaxis.set_major_formatter(FixedFormatter(['a', "b", 'c', "d", 'e', "f", 'g']))

ax.grid()
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_13436\1829023749.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.xaxis.set_major_formatter(FixedFormatter(['a', "b", 'c', "d", 'e', "f", 'g']))

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import (IndexLocator, MultipleLocator, FixedLocator, NullFormatter, FormatStrFormatter, FuncFormatter, 
ScalarFormatter, FixedFormatter)

fig = plt.figure(figsize=(7,4))
ax = fig.subplots()

x = np.arange(-np.pi/2, np.pi, 0.1)
y = np.sin(x)

ax.plot(x, y * 1e5)

ax.xaxis.set_major_locator(FixedLocator([-1, 0, 1, 3]))
ax.xaxis.set_major_formatter(FixedFormatter(['a', "b", 'c', "d", 'e', "f", 'g']))

ax.grid()
plt.show()
